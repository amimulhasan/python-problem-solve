# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python-problem-solve/blob/main/Employee_Record_Management_System_(Python_OOP)_python_Copy_Edit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Employee:
    def __init__(self, emp_id, name, role, salary):
        self.emp_id = emp_id
        self.name = name
        self.role = role
        self.salary = salary

    def display_info(self):
        print(f"ID: {self.emp_id}, Name: {self.name}, Role: {self.role}, Salary: {self.salary}")


class EmployeeManager:
    def __init__(self):
        self.employees = []

    def add_employee(self, employee):
        self.employees.append(employee)
        print("✅ Employee added successfully!")

    def view_all_employees(self):
        if not self.employees:
            print("❌ No employees found.")
        else:
            print("\n📋 Employee List:")
            for emp in self.employees:
                emp.display_info()

    def search_employee(self, emp_id):
        for emp in self.employees:
            if emp.emp_id == emp_id:
                print("🔍 Employee Found:")
                emp.display_info()
                return
        print("❌ Employee not found.")

    def delete_employee(self, emp_id):
        for emp in self.employees:
            if emp.emp_id == emp_id:
                self.employees.remove(emp)
                print("🗑️ Employee deleted.")
                return
        print("❌ Employee not found.")


# Main Program
manager = EmployeeManager()

while True:
    print("\n===== Employee Management Menu =====")
    print("1. Add Employee")
    print("2. View All Employees")
    print("3. Search Employee by ID")
    print("4. Delete Employee by ID")
    print("5. Exit")

    choice = input("Choose an option: ")

    if choice == '1':
        emp_id = input("Enter Employee ID: ")
        name = input("Enter Name: ")
        role = input("Enter Role: ")
        salary = float(input("Enter Salary: "))
        emp = Employee(emp_id, name, role, salary)
        manager.add_employee(emp)

    elif choice == '2':
        manager.view_all_employees()

    elif choice == '3':
        search_id = input("Enter Employee ID to search: ")
        manager.search_employee(search_id)

    elif choice == '4':
        delete_id = input("Enter Employee ID to delete: ")
        manager.delete_employee(delete_id)

    elif choice == '5':
        print("👋 Exiting Employee Manager. Goodbye!")
        break

    else:
        print("⚠️ Invalid option. Try again.")
# Out:
# ===== Employee Management Menu =====
# 1. Add Employee
# 2. View All Employees
# 3. Search Employee by ID
# 4. Delete Employee by ID
# 5. Exit
# Choose an option: 1
# Enter Employee ID: 234
# Enter Name: hhk
# Enter Role: sjds
# Enter Salary: 3465858
# ✅ Employee added successfully!
#
# ===== Employee Management Menu =====
# 1. Add Employee
# 2. View All Employees
# 3. Search Employee by ID
# 4. Delete Employee by ID
# 5. Exit
# Choose an option: 2
#
# 📋 Employee List:
# ID: 234, Name: hhk, Role: sjds, Salary: 3465858.0
#
# ===== Employee Management Menu =====
# 1. Add Employee
# 2. View All Employees
# 3. Search Employee by ID
# 4. Delete Employee by ID
# 5. Exit
# Choose an option: 3
# Enter Employee ID to search: 234
# 🔍 Employee Found:
# ID: 234, Name: hhk, Role: sjds, Salary: 3465858.0
#
# ===== Employee Management Menu =====
# 1. Add Employee
# 2. View All Employees
# 3. Search Employee by ID
# 4. Delete Employee by ID
# 5. Exit
# Choose an option: 4
# ...

# %%
class Employee:
  def __init__(self,emp_id,name,role,salary):
    self.emp_id=emp_id
    self.name=name
    self.role=role
    self.salary=salary
  def display_info(self):
    print(f"ID:{self.emp_id},Name:{self.name},Role:{self.role},Salary:{self.salary}")
class EmployeeManager:
  def __init__self(self):
    self.employees=[]
  def add_employee(self, employee):
      self.employees.append(employee)
      print("✅ Employee added successfully!")
  def view_all_employees(self):
    if not self.employee:
      print("No Employee found.")
    else:
      print("Employee List:")
      for employee in self.employees:
        employee.display_info()
  def search_employee(self,emp_id):
    for employee in self.employees:
      if employee.emp_id==emp_id:
        print("Employee Found.")
        emp.display_info()
        return
    print("Employee not Found.")
  def remove_employee(self,emp_id):
    for employee in self.employees:
      if employee.emp.self==emp_id:
        self.employees.remove(employee)
        print("Employee removed successfully.")
        return
    print("Employee not found.")
manager=EmployeeManager()
while True:
  print("Employee Management menu:")
  print("1.added employee.")
  print("2.view all employees.")
  print("3.search employee.")
  print("4.Remove employee.")
  print("5.Exit.")
  choice=input("Choice your option:")
  if choice=='1':
    emp_id=input("Enter employee ID:")
    name=input("Enter employee name:")
    role=input("enter employee role:")
    salary=float(input("Enter your salary:"))
    emp=Employee(emp_id,name,role,salary)
    manager.add_employee(emp)
  elif choice=='2':
    manager.view_all_employees()
  elif choice=='3':
    emp_id=input("Enter employee ID to search:")
    manager.search_employee(emp_id)
  elif choice=='4':
    delete_id=input("Enter Employee ID to delete:")
    manager.remove_employee(emp_id)
  elif choice=='5':
    print("Exit the program.")
    break
  else:
    print("Invalid choice.Please Try again.")
# Out:
# Employee Management menu:
# 1.added employee.
# 2.view all employees.
# 3.search employee.
# 4.Remove employee.
# 5.Exit.
# Choice your option:1
# Enter employee ID:45
# Enter employee name:rt
# enter employee role:ty
# Enter your salary:5678
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-d40e44f514c6> in <cell line: 0>()
#      49     salary=float(input("Enter your salary:"))
#      50     emp=Employee(emp_id,name,role,salary)
# ---> 51     manager.add_employee(emp)
#      52   elif choice=='2':
#      53     manager.view_all_employees()
#
# <ipython-input-12-d40e44f514c6> in add_employee(self, employee)
#      11     self.employees=[]
#      12   def add_employee(self, employee):
# ---> 13       self.employees.append(employee)
#      14       print("✅ Employee added successfully!")
#      15   def view_all_employees(self):
#
# ...
