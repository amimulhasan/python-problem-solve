# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python-problem-solve/blob/main/Set_Subset_Check_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Given two sets A and B, write a Python program to check if set A is a subset of set B and print the result.
A={1,2,3,4,5,6,7,8}
B={4,5,6,7}
is_subset=A.issubset(B)
print('Set A ia a subset of B:' if is_subset else 'Set A is not a subset of B:')

# if A <= B:
#     print("Set A is a subset of Set B.")
# else:
#     print("Set A is NOT a subset of Set B.")
# Out:
# Set A is not a subset of B:
