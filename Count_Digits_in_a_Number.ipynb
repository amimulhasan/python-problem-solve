# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python-problem-solve/blob/main/Count_Digits_in_a_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Count Digits in a Number: Write a Python program using a while loop to count the number of digits in a given integer N.

# Count Digits in a Number using while loop

N = int(input("Enter an integer: "))

# Handle negative numbers
num = abs(N)

# Special case when N is 0
if num == 0:
    count = 1
else:
    count = 0
    while num > 0:
        num //= 10
        count += 1

print("Number of digits:", count)
# Out:
# Enter an integer: 34
# Number of digits: 2
