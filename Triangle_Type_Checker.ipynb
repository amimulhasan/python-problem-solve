# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python-problem-solve/blob/main/Triangle_Type_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write a Python program that takes three sides of a triangle as input and determines whether it forms an equilateral, isosceles, or scalene triangle.



def triangle_type(a, b, c):
    # Check for a valid triangle
    if a + b > c and a + c > b and b + c > a:
        if a == b == c:
            return "Equilateral Triangle"
        elif a == b or a == c or b == c:
            return "Isosceles Triangle"
        else:
            return "Scalene Triangle"
    else:
        return "Not a valid triangle"

# Taking input from the user
a = float(input("Enter the length of the first side: "))
b = float(input("Enter the length of the second side: "))
c = float(input("Enter the length of the third side: "))

# Determining the type of triangle
print("Triangle Type:", triangle_type(a, b, c))
