# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python-problem-solve/blob/main/151_Reverse_Words_in_a_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reverse_words(s):
    words = s.strip().split()        # Remove leading/trailing spaces and split by whitespace
    reversed_words = words[::-1]     # Reverse the list of words
    return ' '.join(reversed_words)  # Join them with a single space
s = "  Hello   world!  "
result = reverse_words(s)
print(result)
# Out:
# world! Hello
