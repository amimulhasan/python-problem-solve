# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python-problem-solve/blob/main/Write_a_Python_program_that_takes_an_element_as_input_and_checks_if_it_exists_in_a_given_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_element_in_tuple(tup, element):
    return element in tup

# Example tuple
my_tuple = (10, 20, 30, 40, 50)

# User input
element = input("Enter an element to check: ")

# Convert input to integer if applicable
if element.isdigit():
    element = int(element)

# Check if element exists in tuple
if check_element_in_tuple(my_tuple, element):
    print(f"{element} exists in the tuple.")
else:
    print(f"{element} does not exist in the tuple.")
