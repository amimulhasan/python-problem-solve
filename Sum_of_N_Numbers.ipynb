# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python-problem-solve/blob/main/Sum_of_N_Numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write a Python program using a for loop to calculate the sum of the first N natural numbers, where N is taken as input from the user.



num=int(input('Enter an integer number:'))
sum=0
for i in range(1,num+1):
  sum +=i

print(sum)
# Out:
# Enter an integer number:4
# 10

# %%
try:
  num=int(input('Enter an integer number:'))
  if num<0:
    print('Please enter a non-negative integer.')
  else:
    total=0
    for i in range(1,num+1):
      total +=i


    print(total)
except ValueError:
  print('invalid number!Please enter a valid number. ')
# Out:
# Enter an integer number:2
# 3
